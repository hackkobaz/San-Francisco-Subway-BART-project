# %% [markdown]
# # San Francisco Subway BART project

# %% [markdown]
# <img src='bart.jpg'>

# %% [raw]
# About the Dataset
# Context:
# BART is short for "Bay Area Rapid Transit" and is the transportation system that divides the San Francisco Bay Area in California. BART operates six routes, 46 stations, and 112 miles of track. It serves an average of 423,000 passengers on a weekday, making it the fifth-busiest rapid transit system in the United States.
#
# This dataset contains daily information on BART ridership for all of 2016 and part of 2017. Unlike some other rapid transit datasets, this data includes movements between specific stations (there are a little over 2,000 station-to-station combinations).
#
# Content:
# This dataset is divided into three files. station_info.csv Contains general information about individual stations. date-hour-soo-dest-2017.csv Contains (part of) daily station-to-station trips for 2017. date-hour-soo-dest-2016.csv Includes daily station-to-station trips for the entire 2016.
#
# Thanks...
# I would like to thank BART for recording the data and sharing it with the public.

# %% [markdown]
# ## Project requirements:
# + Which BART station is the busiest?
# + Which is the least popular BART route?
# + When is the best time to go to San Francisco?
# + Which day of the week is the busiest?
# + How many people ride BART late at night?
# + Is there ever a BART station where no one gets on or off?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.pairwise import haversine_distances
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None) 
pd.set_option('display.max_rows', None)

# %%
df1=pd.read_csv('date-hour-soo-dest-2016.csv')
df2=pd.read_csv('date-hour-soo-dest-2017.csv')
df3=pd.read_csv('station_info.csv')

# %%
df1.head()
# Out:
#   Origin Destination  Throughput             DateTime
# 0   12TH        12TH           1  2016-01-01 00:00:00
# 1   12TH        16TH           1  2016-01-01 00:00:00
# 2   12TH        24TH           4  2016-01-01 00:00:00
# 3   12TH        ASHB           4  2016-01-01 00:00:00
# 4   12TH        BALB           2  2016-01-01 00:00:00

# %%
df2.head()
# Out:
#   Origin Destination  Throughput             DateTime
# 0   12TH        19TH           1  2017-01-01 00:00:00
# 1   12TH        24TH           2  2017-01-01 00:00:00
# 2   12TH        BAYF           1  2017-01-01 00:00:00
# 3   12TH        CIVC           5  2017-01-01 00:00:00
# 4   12TH        COLS           2  2017-01-01 00:00:00

# %%
df=pd.concat([df1,df2], ignore_index=True)
# We combine df1 and df2..

# %%
df.head()
# Out:
#   Origin Destination  Throughput             DateTime
# 0   12TH        12TH           1  2016-01-01 00:00:00
# 1   12TH        16TH           1  2016-01-01 00:00:00
# 2   12TH        24TH           4  2016-01-01 00:00:00
# 3   12TH        ASHB           4  2016-01-01 00:00:00
# 4   12TH        BALB           2  2016-01-01 00:00:00

# %%
df3.head()
# Out:
#   Abbreviation                                        Description  \
# 0         12TH  1245 Broadway, Oakland CA 94612<br />12th St. ...
# 1         16TH  2000 Mission Street, San Francisco CA 94110<br...
# 2         19TH  1900 Broadway, Oakland CA 94612<br />19th Stre...
# 3         24TH  2800 Mission Street, San Francisco CA 94110<br...
# 4         ASHB  3100 Adeline Street, Berkeley CA 94703<br />As...
#
#                   Location                                 Name
# 0  -122.271450,37.803768,0  12th St. Oakland City Center (12TH)
# 1  -122.419694,37.765062,0              16th St. Mission (16TH)
# 2  -122.268602,37.808350,0              19th St. Oakland (19TH)
# 3  -122.418143,37.752470,0              24th St. Mission (24TH)
# 4  -122.270062,37.852803,0                         Ashby (ASHB)

# %%
df=pd.merge(df, df3, left_on="Origin", right_on="Abbreviation")
# With the merge command, we merge the "Origin" column in df with the "Abbreviatio" column in df3. We obtain a new df.

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#   Origin Destination  Throughput             DateTime Abbreviation  \
# 0   12TH        12TH           1  2016-01-01 00:00:00         12TH
# 1   12TH        16TH           1  2016-01-01 00:00:00         12TH
# 2   12TH        24TH           4  2016-01-01 00:00:00         12TH
# 3   12TH        ASHB           4  2016-01-01 00:00:00         12TH
# 4   12TH        BALB           2  2016-01-01 00:00:00         12TH
#
#                                          Description                 Location  \
# 0  1245 Broadway, Oakland CA 94612<br />12th St. ...  -122.271450,37.803768,0
# 1  1245 Broadway, Oakland CA 94612<br />12th St. ...  -122.271450,37.803768,0
# 2  1245 Broadway, Oakland CA 94612<br />12th St. ...  -122.271450,37.803768,0
# 3  1245 Broadway, Oakland CA 94612<br />12th St. ...  -122.271450,37.803768,0
# 4  1245 Broadway, Oakland CA 94612<br />12th St. ...  -122.271450,37.803768,0
#
#                                   Name
# 0  12th St. Oakland City Center (12TH)
# ...

# %%
df["Origin"].value_counts()
# Out:
# Origin
# POWL    424161
# CIVC    414949
# EMBR    414424
# MONT    410690
# 16TH    379041
# DBRK    371996
# 12TH    371398
# 24TH    370851
# 19TH    365911
# SFIA    356462
# MCAR    354558
# FTVL    339221
# DALY    330412
# COLS    328262
# DELN    320289
# BALB    319333
# LAKE    314174
# FRMT    311081
# GLEN    304206
# SANL    301214
# ASHB    291354
# BAYF    290326
# PITT    289539
# CONC    287980
# HAYW    286075
# WCRK    285019
# WOAK    281927
# RICH    277297
# DUBL    275537
# ROCK    273886
# NBRK    263774
# PLZA    261962
# PHIL    258156
# MLBR    257040
# UCTY    241990
# SBRN    234442
# SHAY    223514
# OAKL    220234
# COLM    210347
# WDUB    206153
# SSAN    204748
# LAFY    199035
# CAST    197316
# ORIN    181585
# NCON    167898
# Name: count, dtype: int64

# %%
# We check how many rows the columns have with the unique code.

# %%
df["Origin"].nunique()
# Out:
# 45

# %%
df["Destination"].nunique()
# Out:
# 46

# %%
df["Throughput"].nunique()
# Out:
# 950

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13269767 entries, 0 to 13269766
# Data columns (total 8 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Origin        object
#  1   Destination   object
#  2   Throughput    int64
#  3   DateTime      object
#  4   Abbreviation  object
#  5   Description   object
#  6   Location      object
#  7   Name          object
# dtypes: int64(1), object(7)
# memory usage: 809.9+ MB

# %%
df.isnull().sum()
# We do not have any empty data.
# Out:
# Origin          0
# Destination     0
# Throughput      0
# DateTime        0
# Abbreviation    0
# Description     0
# Location        0
# Name            0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
# We convert the data in the DateTime column into numeric values ​​that the machine can read as day, month and year.

# %%
df["DateTime"]=pd.to_datetime(df["DateTime"])

# %%
df["Year"]=df["DateTime"].dt.year
df["Month"]=df["DateTime"].dt.month
df["Day"]=df["DateTime"].dt.day
df["Month_Name"]=df["DateTime"].dt.month_name()
df["Day_Name"]=df["DateTime"].dt.day_name()
df["Hour"]=df["DateTime"].dt.hour

# %%
df.head()
# Out:
#   Origin Destination  Throughput  Year  Month  Day Month_Name Day_Name  Hour  \
# 0   12TH        12TH           1  2016      1    1    January   Friday     0
# 1   12TH        16TH           1  2016      1    1    January   Friday     0
# 2   12TH        24TH           4  2016      1    1    January   Friday     0
# 3   12TH        ASHB           4  2016      1    1    January   Friday     0
# 4   12TH        BALB           2  2016      1    1    January   Friday     0
#
#    longitude   latitude
# 0 -122.27145  37.803768
# 1 -122.27145  37.803768
# 2 -122.27145  37.803768
# 3 -122.27145  37.803768
# 4 -122.27145  37.803768

# %%
df["longitude"]=df["Location"].apply(lambda x:float(x.split(",")[0]))
df["latitude"]=df["Location"].apply(lambda x: float(x.split(",")[1]))
# We separate the seemingly mixed latitude and longitude values ​​in the Location column into two columns [longitude and latitude].

# %%
df=df.drop(["DateTime","Description","Location","Name","Abbreviation"],axis=1)

# %% [raw]
# # Description: The description column is no longer needed, because we determined the locations of the stations as latitude and longitude.
# # We separated it as DateTime year-month-day, now we can delete it.
# # Since we determined the location information as action and longitude, we can delete it.
# # Since we can find the name information from the action and longitude values, this column seems unnecessary.
# # Since Abbreviation is the abbreviation of the names given to the stations, since it is possible to determine the location with the action and longitude columns, we do not need this information. Therefore, we can delete this column too.

# %%
df.sample(3)
# Out:
#         Origin Destination  Throughput  Year  Month  Day Month_Name  \
# 2956029   DBRK        DBRK           4  2016      4   18      April
# 6739658   16TH        COLM           1  2016      9    3  September
# 1470353   HAYW        WCRK           2  2016      2   24   February
#
#           Day_Name  Hour   longitude   latitude
# 2956029     Monday    12 -122.268133  37.870104
# 6739658   Saturday    11 -122.419694  37.765062
# 1470353  Wednesday     8 -122.087018  37.669723

# %%
df["Route"]=df["Origin"]+"-"+df["Destination"]

# %% [raw]
# Since Origin and Destination here indicate the starting point and destination of the journey, we combined this column into a new column named Router.
# We separated these starting and ending points with the line in between.

# %%
df.sample(5)
# Out:
#          Origin Destination  Throughput  Year  Month  Day Month_Name  \
# 732060     GLEN        MLBR           1  2016      1   28    January
# 12750639   CIVC        EMBR           3  2017      4   14      April
# 13123745   UCTY        SANL           3  2017      4   28      April
# 5581226    COLM        LAFY           1  2016      7   22       July
# 2150347    GLEN        HAYW           2  2016      3   19      March
#
#           Day_Name  Hour   longitude   latitude      Route
# 732060    Thursday    13 -122.433817  37.733064  GLEN-MLBR
# 12750639    Friday    22 -122.414123  37.779732  CIVC-EMBR
# 13123745    Friday    15 -122.017388  37.590630  UCTY-SANL
# 5581226     Friday    19 -122.466233  37.684638  COLM-LAFY
# 2150347   Saturday    19 -122.433817  37.733064  GLEN-HAYW

# %% [markdown]
# ## Data Analytics Question
# + Which BART station is busiest?

# %%
throughput_data_origin=df.groupby("Origin")["Throughput"].agg("sum").sort_values(ascending=False)
plt.figure(figsize=(20,10))
sns.barplot(x=throughput_data_origin.index, y=throughput_data_origin.values, palette="viridis")    
plt.xticks(rotation=90);
# Throughput: Indicates the number of passengers carried at each station during the times given. 
# According to the question, we can examine the graph below to see which station was the most crowded.

# %%
throughput_data_destination=df.groupby("Destination")["Throughput"].agg("sum").sort_values(ascending=False)
plt.figure(figsize=(20,10))
sns.barplot(x=throughput_data_destination.index, y=throughput_data_destination.values, palette="viridis")    
plt.xticks(rotation=90);
# Similarly, we can examine the graph below to see the density of passengers at the stations at the destination.

# %% [markdown]
# ### Which is the least preferred BART route?

# %%
plt.figure(figsize=(20,10))
throughput_data_route=(df.groupby("Origin")["Throughput"].sum() + df.groupby("Destination")["Throughput"].sum()).sort_values(ascending=False)
sns.barplot(x=throughput_data_route.index, y=throughput_data_route.values, palette="viridis")    
plt.xticks(rotation=90);
# Here we can see the least preferred stations by looking at the density between the starting and destination points.

# %%
df.groupby("Route")["Throughput"].agg("sum").sort_values(ascending=True)
# We can see the least and most preferred stations by looking at the minimum number of passengers in the journeys between stations.
# Out:
# Route
# SSAN-WSPR         41
# SBRN-WSPR         43
# MLBR-WSPR         45
# COLM-WSPR         54
# ORIN-WSPR         96
# NCON-WSPR        113
# LAFY-WSPR        123
# PHIL-WSPR        241
# WDUB-WSPR        248
# RICH-WSPR        263
# WCRK-WSPR        265
# WOAK-WSPR        304
# OAKL-WSPR        321
# CAST-WSPR        325
# CONC-WSPR        346
# WDUB-NCON        358
# NCON-WDUB        358
# ROCK-WSPR        360
# NBRK-WSPR        427
# GLEN-WSPR        430
# BALB-WSPR        430
# LAFY-CAST        444
# PLZA-WSPR        490
# PITT-WSPR        498
# SFIA-WSPR        533
# DUBL-WSPR        545
# WDUB-ORIN        645
# WDUB-LAFY        660
# CAST-LAFY        707
# LAFY-WDUB        718
# CAST-NCON        741
# ORIN-WDUB        745
# ASHB-WSPR        751
# DELN-WSPR        774
# 24TH-WSPR        780
# DUBL-NCON        789
# NCON-CAST        802
# NCON-DUBL        816
# DALY-WSPR        843
# SHAY-LAFY        848
# COLM-OAKL        859
# LAFY-SHAY        875
# DUBL-LAFY        921
# ...

# %% [raw]
# The abbreviation "SSAN-WSPR" probably represents stations or lines such as "San Jose" and "West San Francisco." The abbreviation "POWL-BALB" probably represents a train station serving "Powell Street" and "Balboa Park."

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13269767 entries, 0 to 13269766
# Data columns (total 12 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Origin       object
#  1   Destination  object
#  2   Throughput   int64
#  3   Year         int32
#  4   Month        int32
#  5   Day          int32
#  6   Month_Name   object
#  7   Day_Name     object
#  8   Hour         int32
#  9   longitude    float64
#  10  latitude     float64
#  11  Route        object
# dtypes: float64(2), int32(4), int64(1), object(5)
# memory usage: 1012.4+ MB

# %%
df["Route"].value_counts()
# With this code, we can see the most and least preferred stations by looking at the number of trips between the start and destination routes.
# Out:
# Route
# POWL-24TH    10102
# 19TH-CIVC     9985
# WOAK-POWL     9962
# 19TH-POWL     9954
# POWL-DELN     9933
# POWL-16TH     9923
# POWL-FTVL     9922
# 12TH-MONT     9910
# 12TH-POWL     9910
# 19TH-EMBR     9899
# CIVC-FTVL     9898
# POWL-RICH     9896
# MONT-24TH     9895
# POWL-DALY     9892
# MCAR-CIVC     9884
# POWL-GLEN     9862
# MCAR-POWL     9854
# EMBR-24TH     9849
# EMBR-DELN     9848
# CIVC-DELN     9838
# MONT-FTVL     9838
# 12TH-CIVC     9835
# MCAR-EMBR     9829
# MONT-DELN     9829
# WOAK-CIVC     9826
# 24TH-POWL     9822
# 16TH-POWL     9820
# DBRK-EMBR     9816
# EMBR-16TH     9811
# POWL-DUBL     9804
# CIVC-24TH     9798
# 24TH-CIVC     9795
# POWL-BALB     9775
# 12TH-EMBR     9774
# 19TH-16TH     9769
# WOAK-EMBR     9765
# POWL-PITT     9754
# EMBR-FTVL     9753
# POWL-COLM     9751
# EMBR-DUBL     9741
# MCAR-MONT     9737
# 16TH-MONT     9732
# POWL-POWL     9731
# DALY-POWL     9720
# 19TH-MONT     9718
# DBRK-POWL     9718
# 24TH-MONT     9717
# ...

# %%
plt.figure(figsize=(20,5))
df.groupby('Route')['Throughput'].sum().sort_values(ascending=True)[:30].plot(kind="bar",colormap="viridis");
# Group unique routes.
# Sort the 30 least dense groups among these routers from smallest to largest

# %% [markdown]
# ## When is the best time to go from Berkeley to San Francisco?
# + Berkeley Station Code => DBRK
#
# + SF Station Code => SSAN
#
# + Route => DBRK-SSAN

# %% [raw]
# To look at the movement between these two stations;

# %%
df[df["Route"]=="DBRK-SSAN"].head()
# Out:
#       Origin Destination  Throughput  Year  Month  Day Month_Name  Day_Name  \
# 1962    DBRK        SSAN           2  2016      1    1    January    Friday
# 19290   DBRK        SSAN           2  2016      1    1    January    Friday
# 21347   DBRK        SSAN           3  2016      1    1    January    Friday
# 31132   DBRK        SSAN           1  2016      1    2    January  Saturday
# 38101   DBRK        SSAN           1  2016      1    2    January  Saturday
#
#        Hour   longitude   latitude      Route
# 1962      2 -122.268133  37.870104  DBRK-SSAN
# 19290    21 -122.268133  37.870104  DBRK-SSAN
# 21347    23 -122.268133  37.870104  DBRK-SSAN
# 31132    13 -122.268133  37.870104  DBRK-SSAN
# 38101    18 -122.268133  37.870104  DBRK-SSAN

# %%
df[df["Route"]=="DBRK-SSAN"].groupby(["Hour","Day_Name"])["Throughput"].sum().sort_values()
# To list the days with the least passengers:
# Out:
# Hour  Day_Name
# 1     Thursday       1
#       Wednesday      2
#       Monday         2
# 2     Friday         2
# 3     Sunday         2
# 2     Sunday         5
# 1     Tuesday        5
# 8     Sunday         5
# 7     Saturday       8
# 8     Saturday      10
# 0     Monday        12
# 1     Friday        15
# 6     Friday        18
# 9     Sunday        18
# 5     Monday        21
# 0     Tuesday       22
#       Thursday      22
# 6     Thursday      23
# 10    Sunday        24
# 9     Saturday      25
# 5     Wednesday     25
# 6     Tuesday       26
# 23    Sunday        29
# 5     Thursday      30
#       Tuesday       30
# 6     Wednesday     30
# 5     Friday        31
# 10    Monday        32
# 12    Sunday        32
# 11    Wednesday     33
# 23    Monday        34
# 11    Tuesday       34
# 13    Sunday        35
# 0     Wednesday     35
# 21    Sunday        38
# 12    Wednesday     38
# 14    Sunday        39
# 12    Tuesday       40
# 10    Saturday      41
# ...

# %%
df[df["Route"]=="DBRK-SSAN"].groupby(["Hour","Day_Name"])["Throughput"].sum().sort_values()[:10].plot.bar(colormap="viridis");

# %%
# We found Thursday to be the day with the fewest passengers.

# %% [markdown]
# ## Which day of the week is the busiest?

# %% [raw]
# I used the code below to indicate the highest number of passengers traveling on the day
# This time ascending=False was used so it sorted from the busiest to the lowest.

# %%
df.groupby("Day_Name")["Throughput"].sum().sort_values(ascending=False)
# Out:
# Day_Name
# Wednesday    30661163
# Tuesday      30334044
# Thursday     30037586
# Friday       28362453
# Monday       26953148
# Saturday     13689839
# Sunday        9597632
# Name: Throughput, dtype: int64

# %%
df.groupby("Day_Name")["Throughput"].sum().sort_values(ascending=False).plot.bar();

# %% [markdown]
# ## How many people ride BART late at night?

# %%
df["Hour"].value_counts()
# Out:
# Hour
# 17    808632
# 18    803665
# 16    781518
# 19    744586
# 9     743362
# 15    739185
# 8     734705
# 14    710178
# 10    703194
# 13    699798
# 12    691901
# 11    689756
# 20    658982
# 7     645591
# 21    624213
# 22    588265
# 6     523709
# 23    497980
# 0     356428
# 5     325219
# 1     114341
# 4      81079
# 2       1936
# 3       1544
# Name: count, dtype: int64

# %%
df[(df["Hour"]>21) | (df["Hour"]<8)]["Throughput"].sum()
# Out:
# np.int64(28004116)

# %% [markdown]
# # Data Science Questions
# + Calculate the straight line distance between each station

# %%
df["latitude_radians"]=np.radians(df["latitude"])
df["longitude_radians"]=np.radians(df["longitude"])

# %% [raw]
# The np.radians() function is a function of the NumPy library and converts angles given in degrees to radians. Conversion of Latitude Values: In geographic calculations and trigonometric operations, angles often need to be converted to radians. This conversion is especially important in operations such as distance calculations or angle calculations.

# %%
df.head()
# Out:
#   Origin Destination  Throughput  Year  Month  Day Month_Name Day_Name  Hour  \
# 0   12TH        12TH           1  2016      1    1    January   Friday     0
# 1   12TH        16TH           1  2016      1    1    January   Friday     0
# 2   12TH        24TH           4  2016      1    1    January   Friday     0
# 3   12TH        ASHB           4  2016      1    1    January   Friday     0
# 4   12TH        BALB           2  2016      1    1    January   Friday     0
#
#    longitude   latitude      Route  latitude_radians  longitude_radians
# 0 -122.27145  37.803768  12TH-12TH            0.6598          -2.134039
# 1 -122.27145  37.803768  12TH-16TH            0.6598          -2.134039
# 2 -122.27145  37.803768  12TH-24TH            0.6598          -2.134039
# 3 -122.27145  37.803768  12TH-ASHB            0.6598          -2.134039
# 4 -122.27145  37.803768  12TH-BALB            0.6598          -2.134039

# %%
unique_df=df.drop_duplicates(subset=["Origin"],ignore_index=True)
unique_df=unique_df[["latitude_radians","longitude_radians","Origin"]]
unique_df.head()
# Out:
#    latitude_radians  longitude_radians Origin
# 0          0.659800          -2.134039   12TH
# 1          0.659125          -2.136627   16TH
# 2          0.659880          -2.133990   19TH
# 3          0.658905          -2.136600   24TH
# 4          0.660656          -2.134015   ASHB

# %%
coordinates=unique_df[["latitude_radians","longitude_radians"]].to_numpy()
distances=haversine_distances(coordinates,coordinates)

# %% [raw]
# This code snippet takes the unique coordinates in the unique_df DataFrame and calculates the distances between these coordinates, turning them into a distance matrix.
# This matrix shows the distance between each pair of coordinates.
# The Haversine formula calculates these distances accurately, taking into account the spherical nature of the Earth.

# %%
distances_km=distances*6371

# %% [raw]
# The number 6371 represents the mean radius of the Earth, and it converts distances calculated in radians to kilometers using this number. It creates a new variable called distances_km by converting the angular distances in the distances matrix to real distances (in kilometers). This allows you to express the distances between two points in kilometers.

# %%
distances_km_df=pd.DataFrame(
    distances_km,
    index=unique_df["Origin"],
    columns=unique_df["Origin"]
)

# %%
distances_km_df 
# Shows the distance between BART stations.
# Out:
# Origin       12TH       16TH       19TH       24TH       ASHB       BALB  \
# Origin
# 12TH     0.000000  13.720175   0.567617  14.097927   5.453806  17.972899
# 16TH    13.720175   0.000000  14.123076   1.406790  16.370223   5.417745
# 19TH     0.567617  14.123076   0.000000  14.537177   4.944611  18.449743
# 24TH    14.097927   1.406790  14.537177   0.000000  17.138578   4.296647
# ASHB     5.453806  16.370223   4.944611  17.138578   0.000000  21.355016
# BALB    17.972899   5.417745  18.449743   4.296647  21.355016   0.000000
# BAYF    17.421986  26.873362  17.594397  26.382151  21.438504  28.370186
# CAST    21.318066  31.369785  21.423040  30.899845  24.836544  32.896601
# CIVC    12.818548   1.703137  13.176704   3.051922  15.038489   7.100637
# COLM    21.651800   9.834954  22.162579   8.647687  25.435815   4.426359
# COLS     8.602724  19.629420   8.759155  19.454198  12.762538  22.326582
# CONC    28.452150  41.399854  27.927226  42.092373  25.053770  46.215044
# ...

# %% [markdown]
# ## Create a model that can predict the number of people commuting between any 2 stations on Bart:
# + How would you approach this?
# + What additional data would you need?
# + How would you like the city or Bart authorities to use your data?

# %%
df_weekday=df[(df["Day_Name"]!="Saturday")| (df["Day_Name"]!="Sunday")]

# %%
df_route=df_weekday.groupby("Route")["Throughput"].mean().reset_index()
df_route.columns=["Route","Average_Throughput"]
df_route["Average_Throughput"] = df_route["Average_Throughput"].astype(int)

# %% [raw]
# Calculates the average Throughput values for each route using the data in the df_weekday DataFrame, organizes the results, and converts the Average_Throughput column to an integer.
# The result is a new DataFrame (df_route) that presents the average throughput values for each route in a more readable format.

# %%
df_weekday=pd.merge(df_weekday, df_route, on="Route")

# %%
df_weekday=df_weekday[(df_weekday["Hour"]==8) |(df_weekday["Hour"]==17)]

# %%
df_weekday['working']=df_weekday['Throughput']-df_weekday['Average_Throughput']

# %%
df_weekday.groupby(['Route','Day_Name'])['working'].sum().sort_values(ascending=False)[:40]
# Out:
# Route      Day_Name
# PHIL-EMBR  Tuesday      44199
#            Wednesday    42265
# BALB-MONT  Tuesday      42261
# 24TH-MONT  Tuesday      42024
#            Wednesday    41359
# BALB-MONT  Wednesday    41356
# PHIL-EMBR  Thursday     40062
# DUBL-EMBR  Tuesday      39914
# BALB-MONT  Thursday     39885
# 24TH-MONT  Thursday     39556
# PHIL-EMBR  Monday       37337
# DUBL-EMBR  Wednesday    37331
# PHIL-MONT  Tuesday      37117
# BALB-MONT  Friday       35661
# PHIL-MONT  Wednesday    35145
# DUBL-EMBR  Thursday     35100
# 24TH-MONT  Monday       34640
# BALB-MONT  Monday       34586
# FRMT-EMBR  Tuesday      34023
# 19TH-EMBR  Tuesday      33819
# PHIL-MONT  Thursday     33768
# 24TH-EMBR  Tuesday      33384
# 19TH-EMBR  Wednesday    33289
# DUBL-EMBR  Monday       33031
# 24TH-EMBR  Wednesday    32719
# 24TH-MONT  Friday       32703
# DALY-MONT  Wednesday    32292
# FRMT-EMBR  Wednesday    32161
# DALY-MONT  Tuesday      32097
# 19TH-EMBR  Thursday     31235
# ...

# %%
df_weekday.groupby(['Day_Name'])['working'].sum().sort_values(ascending=False)
# Out:
# Day_Name
# Tuesday      4634030
# Wednesday    4611762
# Thursday     4400544
# Monday       3827240
# Friday       3615267
# Saturday     -738742
# Sunday      -1065113
# Name: working, dtype: int64

# %%
df_weekday.groupby('Route')['working'].sum().sort_values(ascending=False)[:40].plot.bar()
# Out:
# <Axes: xlabel='Route'>

# %%
df_weekday['working'].sum()
# Out:
# np.int64(19284988)

# %% [raw]
# The BALB-MONT route has the highest number of working individuals of all routes.
# Tuesday is also the day that BART is used the most by working individuals overall.

# %% [raw]
# 1. Approach
# It would be logical to follow the following steps in the model creation process:
#
# Data Analysis: First, analyze the existing datasets (2016 and 2017 passenger numbers) in detail. It is important to understand the seasonal changes in passenger numbers in this data.
#
# Feature Selection: Determine the features required for the model. This may include elements such as geographical locations of stations, historical passenger data, hourly trip counts.
#
# Model Selection: Develop a model that predicts passenger numbers using methods such as regression analysis or time series forecasting. Machine learning algorithms (e.g. random forest, support vector machines) can also be used.
#
# Training and Testing the Model: Train the model on the existing data and then evaluate its accuracy on the test set.
#
# 2. Additional Data
# The following additional data may be needed for the prediction:
#
# Weather Data: Weather conditions can affect public transport usage. Passenger numbers may change, especially on rainy or extremely hot days.
#
# Specialized Survey Data: Information such as ridership habits, frequency of commutes, and preferred times.
#
# Urban Planning Data: Data such as new construction projects, workplace locations, and demographic changes.
#
# Traffic Data: Factors such as vehicle traffic and bike lanes can also affect transit use.
#
# 3. Usage Recommendations
# City or BART officials can use data in the following ways:
#
# Planning and Development: Identifying new lines or stations, estimating ridership to improve existing lines.
#
# Service Improvement: Offering additional services during peak hours or rerouting to specific routes.
#
# Social Media and Marketing: Communicating increases or decreases in ridership to target audiences, organizing information campaigns to encourage transit use.
#
# Policy Development: Assisting with data-based decision-making in urban transportation policy-making.
#
# This approach allows BART to more accurately estimate ridership and improve service.
